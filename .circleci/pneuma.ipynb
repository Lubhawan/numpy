# %%
import pandas as pd

# %%
df = pd.read_excel("Crimes_-_2001_to_Present_20250527 (1).xlsx")

# %%
df.describe()
# Out:
#                Beat      District          Ward  Community Area  X Coordinate  \
# count  50267.000000  50267.000000  50267.000000    50266.000000  5.023600e+04
# mean    1144.283844     11.213122     23.068435       36.584073  1.165526e+06
# std      705.941046      7.054900     13.842874       21.523639  1.643659e+04
# min      111.000000      1.000000      1.000000        1.000000  1.093568e+06
# 25%      532.000000      5.000000     10.000000       23.000000  1.153977e+06
# 50%     1031.000000     10.000000     23.000000       32.000000  1.167456e+06
# 75%     1724.000000     17.000000     34.000000       53.000000  1.176818e+06
# max     2535.000000     31.000000     50.000000       77.000000  1.205119e+06
#
#        Y Coordinate     Year      Latitude     Longitude
# count  5.023600e+04  50267.0  50236.000000  50236.000000
# mean   1.886913e+06   2025.0     41.845267    -87.668071
# std    3.143801e+04      0.0      0.086456      0.059849
# ...

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Block', 'IUCR', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'FBI Code', 'X Coordinate', 'Y Coordinate',
#        'Year', 'Updated On', 'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %%
df.head()
# Out:
#   Case Number                    Date                Block  IUCR  \
# 0    JJ260129  05/18/2025 12:00:00 AM     034XX N CLARK ST  0460
# 1    JJ260746  05/18/2025 12:00:00 AM  022XX N LINCOLN AVE  0870
# 2    JJ259628  05/18/2025 12:00:00 AM   088XX S BURLEY AVE  0820
# 3    JJ259414  05/18/2025 12:00:00 AM    067XX S EVANS AVE  0497
# 4    JJ259766  05/18/2025 12:00:00 AM  006XX N FRANKLIN ST  1310
#
#       Primary Type                                        Description  \
# 0          BATTERY                                             SIMPLE
# 1            THEFT                                     POCKET-PICKING
# 2            THEFT                                     $500 AND UNDER
# 3          BATTERY  AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS ...
# 4  CRIMINAL DAMAGE                                        TO PROPERTY
#
#   Location Description  Arrest  Domestic  Beat  ...  Ward  Community Area  \
# 0        BAR OR TAVERN   False     False  1924  ...    44             6.0
# ...

# %%
# Out:
# <bound method NDFrame.describe of       Case Number                    Date                  Block  IUCR  \
# 0        JJ260129  05/18/2025 12:00:00 AM       034XX N CLARK ST  0460
# 1        JJ260746  05/18/2025 12:00:00 AM    022XX N LINCOLN AVE  0870
# 2        JJ259628  05/18/2025 12:00:00 AM     088XX S BURLEY AVE  0820
# 3        JJ259414  05/18/2025 12:00:00 AM      067XX S EVANS AVE  0497
# 4        JJ259766  05/18/2025 12:00:00 AM    006XX N FRANKLIN ST  1310
# ...           ...                     ...                    ...   ...
# 50262    JJ163966  02/27/2025 10:46:00 AM  050XX S Hermitage ave  1130
# 50263    JJ163639  02/27/2025 10:45:00 AM        003XX W 64TH ST  0460
# 50264    JJ163666  02/27/2025 10:45:00 AM        023XX W 21ST ST  0486
# 50265    JJ163621  02/27/2025 10:44:00 AM   007XX N FAIRBANKS CT  1345
# 50266    JJ163645  02/27/2025 10:36:00 AM     080XX S HALSTED ST  051A
#
#              Primary Type                                        Description  \
# ...

# %%
import os
import json
from pneuma import Pneuma

# %%
import torch

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
pneuma = Pneuma(
    out_path="my_pneuma_output",
    use_local_model=True,  # This enables HF models
    llm_path="Qwen/Qwen2.5-7B-Instruct",  # HF model for text generation
    embed_path="BAAI/bge-base-en-v1.5",   # HF model for embeddings
    hf_token="your_token_here",  # Optional: for gated models
    max_llm_batch_size=2,  # Adjust based on your GPU memory
)
